# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatrichopade11/construction_cost_estimation/blob/main/Fear_%26_Greed_Index_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
uploaded = files.upload()
# Out:
# Mounted at /content/drive
#      <input type="file" id="files-477c25ca-221e-4326-9f1b-873a8267bb0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-477c25ca-221e-4326-9f1b-873a8267bb0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
fg = pd.read_csv("dataset.csv")
fg.head()
# Out:
#          Date  Value Value_Classification  BTC_Closing   BTC_Volume
# 0  2018-02-01   30.0                 Fear  9170.540039   9959400448
# 1  2018-02-02   15.0         Extreme Fear  8830.750000  12726899712
# 2  2018-02-03   40.0                 Fear  9174.910156   7263790080
# 3  2018-02-04   24.0         Extreme Fear  8277.009766   7073549824
# 4  2018-02-05   11.0         Extreme Fear  6955.270020   9285289984

# %%
#structure
fg.shape
# Out:
# (1885, 5)

# %%
fg.columns
# Out:
# Index(['Date', 'Value', 'Value_Classification', 'BTC_Closing', 'BTC_Volume'], dtype='object')

# %%
fg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1885 entries, 0 to 1884
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1885 non-null   object
#  1   Value                 1882 non-null   float64
#  2   Value_Classification  1882 non-null   object
#  3   BTC_Closing           1885 non-null   float64
#  4   BTC_Volume            1885 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 73.8+ KB

# %%
fg.columns
# Out:
# Index(['Date', 'Value', 'Value_Classification', 'BTC_Closing', 'BTC_Volume'], dtype='object')

# %%
fg.head()
# Out:
#         Date  Value Value_Classification  BTC_Closing   BTC_Volume
# 0 2018-02-01   30.0                 Fear  9170.540039   9959400448
# 1 2018-02-02   15.0         Extreme Fear  8830.750000  12726899712
# 2 2018-02-03   40.0                 Fear  9174.910156   7263790080
# 3 2018-02-04   24.0         Extreme Fear  8277.009766   7073549824
# 4 2018-02-05   11.0         Extreme Fear  6955.270020   9285289984

# %%
print(list(fg.columns))
# Out:
# ['level_0', 'index', 'Date', 'Value', 'Value_Classification', 'BTC_Closing', 'BTC_Volume']

# %%
fg.columns = fg.columns.astype(str).str.lower().str.strip()
print(fg.columns)
# Out:
# Index(['level_0', 'index', 'date', 'value', 'value_classification',
#        'btc_closing', 'btc_volume'],
#       dtype='object')

# %%
fg.rename(columns={'value_classification': 'classification'}, inplace=True)

# %%
fg.columns
# Out:
# Index(['level_0', 'index', 'date', 'value', 'classification', 'btc_closing',
#        'btc_volume'],
#       dtype='object')

# %%
fg.groupby('classification').size()
# Out:
# classification
# Extreme Fear     528
# Extreme Greed    185
# Fear             644
# Greed            338
# Neutral          187
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure()
fg['classification'].value_counts().plot(kind='bar')
plt.title("Fear & Greed Market Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
